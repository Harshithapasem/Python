# %%
# !pip install torch-snippets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-snippets in /usr/local/lib/python3.9/dist-packages (0.499.25)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (7.9.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (8.4.0)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.18.0)
# Requirement already satisfied: typing in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (3.7.4.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.10.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (6.0)
# Requirement already satisfied: altair in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (4.2.2)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.13.0)
# Requirement already satisfied: imgaug>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.4.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.5.28)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (3.2.0)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.21.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.3.6)
# Requirement already satisfied: loguru in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.6.0)
# Requirement already satisfied: confection in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.0.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.2.2)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.20.9)
# Requirement already satisfied: lovely-tensors in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (0.1.14)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (4.65.0)
# Requirement already satisfied: srsly in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (2.4.6)
# Requirement already satisfied: catalogue in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (2.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.22.4)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (4.5.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (3.1.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (3.8.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (13.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from torch-snippets) (3.7.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.9/dist-packages (from imgaug>=0.4.0->torch-snippets) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from imgaug>=0.4.0->torch-snippets) (1.16.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.9/dist-packages (from imgaug>=0.4.0->torch-snippets) (2.25.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.9/dist-packages (from imgaug>=0.4.0->torch-snippets) (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from imgaug>=0.4.0->torch-snippets) (4.7.0.72)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from imgaug>=0.4.0->torch-snippets) (1.10.1)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair->torch-snippets) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair->torch-snippets) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair->torch-snippets) (4.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from altair->torch-snippets) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->torch-snippets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->torch-snippets) (2.8.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from fastcore->torch-snippets) (22.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from fastcore->torch-snippets) (23.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (2.14.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (67.6.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->torch-snippets) (0.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from jsonlines->torch-snippets) (22.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from lovely-tensors->torch-snippets) (1.13.1+cu116)
# Requirement already satisfied: lovely-numpy>=0.2.8 in /usr/local/lib/python3.9/dist-packages (from lovely-tensors->torch-snippets) (0.2.8)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->torch-snippets) (4.39.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->torch-snippets) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->torch-snippets) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->torch-snippets) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->torch-snippets) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->torch-snippets) (0.11.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->torch-snippets) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->torch-snippets) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->torch-snippets) (8.1.3)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from pre-commit->torch-snippets) (1.7.0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from pre-commit->torch-snippets) (3.3.1)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pre-commit->torch-snippets) (2.5.21)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.9/dist-packages (from pre-commit->torch-snippets) (20.21.0)
# Requirement already satisfied: Levenshtein==0.20.9 in /usr/local/lib/python3.9/dist-packages (from python-Levenshtein->torch-snippets) (0.20.9)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from Levenshtein==0.20.9->python-Levenshtein->torch-snippets) (2.13.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->torch-snippets) (2.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->torch-snippets) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->torch-snippets) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython->torch-snippets) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair->torch-snippets) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->torch-snippets) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->torch-snippets) (0.2.6)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch-snippets) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch-snippets) (2023.3.15)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch-snippets) (3.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.10.0->pre-commit->torch-snippets) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.10.0->pre-commit->torch-snippets) (3.1.1)
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.9/dist-packages (from virtualenv>=20.10.0->pre-commit->torch-snippets) (3.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->altair->torch-snippets) (2.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython->torch-snippets) (0.7.0)

# %%
# !pip install openimages
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openimages in /usr/local/lib/python3.9/dist-packages (0.0.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from openimages) (4.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from openimages) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openimages) (4.65.0)
# Requirement already satisfied: cvdata in /usr/local/lib/python3.9/dist-packages (from openimages) (0.0.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from openimages) (1.4.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.9/dist-packages (from openimages) (1.26.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from boto3->openimages) (1.0.1)
# Requirement already satisfied: botocore<1.30.0,>=1.29.97 in /usr/local/lib/python3.9/dist-packages (from boto3->openimages) (1.29.97)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from boto3->openimages) (0.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from cvdata->openimages) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from cvdata->openimages) (8.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from cvdata->openimages) (4.7.0.72)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->openimages) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->openimages) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->openimages) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->openimages) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->openimages) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->openimages) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->openimages) (1.16.0)

# %%
# !pip install torchtext==0.6 torch==1.13.1 torchvision==0.14.1 torchaudio==0.13.1 fastai==2.7.11 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torchtext==0.6 in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.9/dist-packages (1.13.1+cu116)
# Requirement already satisfied: torchvision==0.14.1 in /usr/local/lib/python3.9/dist-packages (0.14.1+cu116)
# Requirement already satisfied: torchaudio==0.13.1 in /usr/local/lib/python3.9/dist-packages (0.13.1+cu116)
# Requirement already satisfied: fastai==2.7.11 in /usr/local/lib/python3.9/dist-packages (2.7.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from torchtext==0.6) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchtext==0.6) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from torchtext==0.6) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchtext==0.6) (1.22.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from torchtext==0.6) (0.1.97)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.13.1) (4.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision==0.14.1) (8.4.0)
# Requirement already satisfied: fastcore<1.6,>=1.4.5 in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (1.5.28)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (6.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (1.2.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (22.0.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (3.7.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (0.0.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (1.4.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (23.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (1.10.1)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (3.5.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from fastai==2.7.11) (1.0.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (2.4.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (1.10.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (67.6.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (6.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (3.0.12)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<4->fastai==2.7.11) (0.7.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchtext==0.6) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchtext==0.6) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchtext==0.6) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchtext==0.6) (1.26.15)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->fastai==2.7.11) (4.39.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->fastai==2.7.11) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->fastai==2.7.11) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->fastai==2.7.11) (3.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->fastai==2.7.11) (3.15.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai==2.7.11) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai==2.7.11) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai==2.7.11) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<4->fastai==2.7.11) (2.1.2)

# %%
# Import the relevant packages, define the device
# !wget -O open_images_train_captions.jsonl -q https://storage.googleapis.com/localized-narratives/annotations/open_images_train_v6_captions.jsonl
from torch_snippets import *
import json
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print("Running on device: ", device)

# Loop through the content of the JSON file and fetch the information of the first 100,000 images
with open('open_images_train_captions.jsonl', 'r') as json_file:
    json_list = json_file.read().split('\n')

np.random.shuffle(json_list)
data = []
N = 10000 # Doing 10000 instead of 100000 because cuda runs out of memory

for ix, json_str in Tqdm(enumerate(json_list), N):
    if ix == N: break
    try:
        result = json.loads(json_str)
        x = pd.DataFrame.from_dict(result, orient='index').T
        data.append(x)
    except:
        pass
    

# Split the dataframe (data) into training and validation datasets
np.random.seed(10)

data = pd.concat(data)
data['train'] = np.random.choice([True,False], size=len(data),p=[0.95,0.05])
data.to_csv('data.csv', index=False)


# Download the images corresponding to the image IDs fetched from the JSON file:
from openimages.download import _download_images_by_id
# !mkdir -p train-images val-images
subset_imageIds = data[data['train']].image_id.tolist()
_download_images_by_id(subset_imageIds, 'train', './train-images/')

subset_imageIds = data[~data['train']].image_id.tolist()
_download_images_by_id(subset_imageIds, 'train', './val-images/')
# Out:
# Running on device:  cuda
# 100%|██████████| 10000/10000 [00:11<00:00, 907.99it/s]
#  45%|████▍     | 4279/9530 [01:09<01:22, 63.79it/s]WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: open-images-dataset.s3.amazonaws.com. Connection pool size: 10
# 100%|██████████| 9530/9530 [02:35<00:00, 61.11it/s]
# 100%|██████████| 470/470 [00:07<00:00, 64.39it/s]

# %%
# A vocabulary object is something that can map every word in all the captions to a unique integer and vice versa
from torchtext.data import Field
from pycocotools.coco import COCO
from collections import defaultdict

captions = Field(sequential=False, init_token='<start>', eos_token='<end>')

all_captions = data[data['train']]['caption'].tolist()
all_tokens = [[w.lower() for w in c.split(' ')] for c in all_captions]
all_tokens = [w for sublist in all_tokens for w in sublist]
captions.build_vocab(all_tokens)

# %%
# Captions vocabulary components
class Vocab: pass

vocab = Vocab()
captions.vocab.itos.insert(0, '')
vocab.itos = captions.vocab.itos

vocab.stoi = defaultdict(lambda:captions.vocab.itos.index(''))
vocab.stoi[''] = 0

for s,i in captions.vocab.stoi.items():
    vocab.stoi[s] = i+1

# %%
# Dataset class
from torchvision import transforms
class CaptioningData(Dataset):
    def __init__(self, root, df, vocab):
        self.df = df.reset_index(drop=True)
        self.root = root
        self.vocab = vocab

        self.transform = transforms.Compose([ 
            transforms.Resize(224),
            transforms.RandomCrop(224),
            transforms.RandomHorizontalFlip(), 
            transforms.ToTensor(), 
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))]
        )
    
    # Returns one data pair (image and caption)
    def __getitem__(self, index):
        row = self.df.iloc[index].squeeze()
        id = row.image_id

        image_path = f'{self.root}/{id}.jpg'
        image = Image.open(os.path.join(image_path)).convert('RGB')

        caption = row.caption
        
        tokens = str(caption).lower().split()
        target = []
        target.append(vocab.stoi[''])
        target.extend([vocab.stoi[token] for token in tokens])
        target.append(vocab.stoi[''])
        target = torch.Tensor(target).long()

        return image, target, caption
 
    def choose(self):
        return self[np.random.randint(len(self))]
    
    def __len__(self):
        return len(self.df)
    
    # Creates batch of captions and padds captions to be equal length
    def collate_fn(self, data):
        data.sort(key=lambda x: len(x[1]), reverse=True)
        images, targets, captions = zip(*data)
        images = torch.stack([self.transform(image) for image in images], 0)

        lengths = [len(tar) for tar in targets]
        _targets = torch.zeros(len(captions), max(lengths)).long()

        for i, tar in enumerate(targets):
            end = lengths[i]
            _targets[i, :end] = tar[:end] 

        return images.to(device), _targets.to(device), torch.tensor(lengths).long().to(device)

# %%
#Define the training and validation dataset and data loaders
trn_ds = CaptioningData('train-images', data[data['train']], vocab)

val_ds = CaptioningData('val-images', data[~data['train']], vocab)

# Show sample image and caption
image, target, caption = trn_ds.choose()
show(image, title=caption, sz=5); 
print(target)


# Create the dataloaders for the datasets
trn_dl = DataLoader(trn_ds, 32, collate_fn=trn_ds.collate_fn)
val_dl = DataLoader(val_ds, 32, collate_fn=val_ds.collate_fn)

# A sample batch
inspect(*next(iter(trn_dl)), names='images,targets,lengths')
# Out:
# tensor[21] i64 x∈[4, 3768] μ=390.333 σ=862.248
# ══════════════════════════════════════════════════════════════════
# IMAGES:
# Tensor  Shape: torch.Size([32, 3, 224, 224])    Min: -2.118     Max: 2.640      Mean: -0.221    dtype:
# torch.float32 @ cuda:0
# ══════════════════════════════════════════════════════════════════
# TARGETS:
# Tensor  Shape: torch.Size([32, 89])     Min: 0.000      Max: 5672.000   Mean: 82.003    dtype: torch.int64 @ cuda:0
# ══════════════════════════════════════════════════════════════════
# LENGTHS:
# Tensor  Shape: torch.Size([32]) Min: 10.000     Max: 89.000     Mean: 36.625    dtype: torch.int64 @ cuda:0
# ══════════════════════════════════════════════════════════════════

# %%
from torch.nn.utils.rnn import pack_padded_sequence
from torchvision import models

# The network class - EncoderCNN
class EncoderCNN(nn.Module):
    
    # Load the pretrained ResNet-152 and replace top fc layer
    def __init__(self, embed_size):
        super(EncoderCNN, self).__init__()
        resnet = models.resnet152(pretrained=True)
        for param in resnet.parameters():
          param.requires_grad_(False)

        # Felete the last fc layer.
        modules = list(resnet.children())[:-1] 
        
        # Connect it to a linear layer
        self.resnet = nn.Sequential(*modules)
        self.linear = nn.Linear(resnet.fc.in_features, embed_size)
        
        # Pass it through batch normalization 
        self.bn = nn.BatchNorm1d(embed_size, momentum=0.01)

    # Extract feature vectors from input images
    def forward(self, images):
        with torch.no_grad():
            features = self.resnet(images)

        features = features.reshape(features.size(0), -1)
        features = self.bn(self.linear(features))

        return features

# Creating encoder instance
encoder = EncoderCNN(256).to(device)
# !pip install torch_summary
from torchsummary import summary
print(summary(encoder,torch.zeros(32,3,224,224).to(device)))
# Define the decoder architecture – DecoderRNN
class DecoderRNN(nn.Module):
    
    # Set the hyper-parameters and build the layers
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers, max_seq_length=80):

        super(DecoderRNN, self).__init__()

        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)
        self.max_seq_length = max_seq_length
    
    # Decode image feature vectors and generates captions
    def forward(self, features, captions, lengths):
        embeddings = self.embed(captions)
        embeddings = torch.cat((features.unsqueeze(1), embeddings), 1)

        packed = pack_padded_sequence(embeddings, lengths.cpu(), batch_first=True) 

        outputs, _ = self.lstm(packed)
        outputs = self.linear(outputs[0])
        return outputs
    
    #Generate captions for given image features using greedy search
    def predict(self, features, states=None):
        sampled_ids = []
        inputs = features.unsqueeze(1)
        pdb.set_trace()

        for i in range(self.max_seq_length):
            hiddens, states = self.lstm(inputs, states) # hiddens: (batch_size, 1, hidden_size)

            outputs = self.linear(hiddens.squeeze(1)) # outputs: (batch_size, vocab_size)
            _, predicted = outputs.max(1) # predicted: (batch_size)

            sampled_ids.append(predicted)
            
            inputs = self.embed(predicted) # inputs: (batch_size, embed_size)
            inputs = inputs.unsqueeze(1) # inputs: (batch_size, 1, embed_size)


        sampled_ids = torch.stack(sampled_ids, 1) # sampled_ids: (batch_size, max_seq_length)
        
        # convert predicted tokens to strings
        sentences = []
        for sampled_id in sampled_ids:
            sampled_id = sampled_id.cpu().numpy()
            sampled_caption = []
            
            for word_id in sampled_id:
                word = vocab.itos[word_id]
                #pdb.set_trace()
                sampled_caption.append(word)
                

                #if word == '<end>':
                 #   break

            sentence = ' '.join(sampled_caption)
            pdb.set_trace()
            sentences.append(sentence)

        return sentence
# Trains on a single batch of data
def train_batch(data, encoder, decoder, optimizer, criterion):
    encoder.train()
    decoder.train()

    images, captions, lengths = data
    images = images.to(device)

    captions = captions.to(device)
    targets = pack_padded_sequence(captions, lengths.cpu(), batch_first=True)[0]

    features = encoder(images)
    outputs = decoder(features, captions, lengths)
    loss = criterion(outputs, targets)

    decoder.zero_grad()
    encoder.zero_grad()
    loss.backward()
    optimizer.step()

    return loss
 
    
# Validate on a batch of data
@torch.no_grad()
def validate_batch(data, encoder, decoder, criterion):
    encoder.eval()
    decoder.eval()

    images, captions, lengths = data
    images = images.to(device)

    captions = captions.to(device)
    targets = pack_padded_sequence(captions, lengths.cpu(), batch_first=True)[0]

    features = encoder(images)
    outputs = decoder(features, captions, lengths)

    loss = criterion(outputs, targets)
    return loss
# Define encoder, decoder, loss function, and optimizer
encoder = EncoderCNN(256).to(device)
decoder = DecoderRNN(256, 512, len(vocab.itos), 1).to(device)
criterion = nn.CrossEntropyLoss()
import tensorflow as tf
params = list(decoder.parameters()) + \
         list(encoder.linear.parameters()) + \
         list(encoder.bn.parameters())

optimizer = torch.optim.AdamW(params, lr=1e-3)

n_epochs = 5 # Doing 3 instead of 10 because training on CPU
log = Report(n_epochs)


# Train the model over increasing epochs
for epoch in range(n_epochs):
    if epoch == 3: optimizer = torch.optim.AdamW(params, lr=1e-4)

    N = len(trn_dl)
    for i, data in enumerate(trn_dl):
        trn_loss = train_batch(data, encoder, decoder, optimizer, criterion)
        pos = epoch + (1+i)/N
        log.record(pos=pos, trn_loss=trn_loss, end='\r')

    N = len(val_dl)

    for i, data in enumerate(val_dl):
        val_loss = validate_batch(data, encoder, decoder, criterion)
        pos = epoch + (1+i)/N
        log.record(pos=pos, val_loss=val_loss, end='\r')
        
    log.report_avgs(epoch+1)

log.plot_epochs(log=True)

import pdb
# Generates predictions given an image
def load_image(image_path, transform):
    image = Image.open(image_path).convert('RGB')
    image = image.resize([224, 224], Image.LANCZOS)

    if transform is not None:
        tfm_image = transform(image)[None]

    return image, tfm_image

def load_image_and_predict(image_path):
    transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Normalize((0.485, 0.456, 0.406),(0.229, 0.224, 0.225))
                                    ])

    org_image, tfm_image = load_image(image_path, transform)
    image_tensor = tfm_image.to(device)
    print(image_tensor)
    encoder.eval()
    decoder.eval()
    feature = encoder(image_tensor)
    sentence = decoder.predict(feature)

    
show(org_image, title=sentence)
    #return sentence

# Predict an image
files = Glob('val-images')
load_image_and_predict(choose(files))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch_summary in /usr/local/lib/python3.9/dist-packages (1.4.5)
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 2048, 1, 1]          --
# |    └─Conv2d: 2-1                       [-1, 64, 112, 112]        (9,408)
# |    └─BatchNorm2d: 2-2                  [-1, 64, 112, 112]        (128)
# |    └─ReLU: 2-3                         [-1, 64, 112, 112]        --
# |    └─MaxPool2d: 2-4                    [-1, 64, 56, 56]          --
# |    └─Sequential: 2-5                   [-1, 256, 56, 56]         --
# |    |    └─Bottleneck: 3-1              [-1, 256, 56, 56]         (75,008)
# |    |    └─Bottleneck: 3-2              [-1, 256, 56, 56]         (70,400)
# |    |    └─Bottleneck: 3-3              [-1, 256, 56, 56]         (70,400)
# |    └─Sequential: 2-6                   [-1, 512, 28, 28]         --
# |    |    └─Bottleneck: 3-4              [-1, 512, 28, 28]         (379,392)
# |    |    └─Bottleneck: 3-5              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-6              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-7              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-8              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-9              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-10             [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-11             [-1, 512, 28, 28]         (280,064)
# |    └─Sequential: 2-7                   [-1, 1024, 14, 14]        --
# |    |    └─Bottleneck: 3-12             [-1, 1024, 14, 14]        (1,512,448)
# |    |    └─Bottleneck: 3-13             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-14             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-15             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-16             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-17             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-18             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-19             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-20             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-21             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-22             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-23             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-24             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-25             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-26             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-27             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-28             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-29             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-30             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-31             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-32             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-33             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-34             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-35             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-36             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-37             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-38             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-39             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-40             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-41             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-42             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-43             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-44             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-45             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-46             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-47             [-1, 1024, 14, 14]        (1,117,184)
# |    └─Sequential: 2-8                   [-1, 2048, 7, 7]          --
# |    |    └─Bottleneck: 3-48             [-1, 2048, 7, 7]          (6,039,552)
# |    |    └─Bottleneck: 3-49             [-1, 2048, 7, 7]          (4,462,592)
# |    |    └─Bottleneck: 3-50             [-1, 2048, 7, 7]          (4,462,592)
# |    └─AdaptiveAvgPool2d: 2-9            [-1, 2048, 1, 1]          --
# ├─Linear: 1-2                            [-1, 256]                 524,544
# ├─BatchNorm1d: 1-3                       [-1, 256]                 512
# ==========================================================================================
# Total params: 58,668,864
# Trainable params: 525,056
# Non-trainable params: 58,143,808
# Total mult-adds (G): 11.33
# ==========================================================================================
# Input size (MB): 18.38
# Forward/backward pass size (MB): 321.18
# Params size (MB): 223.80
# Estimated Total Size (MB): 563.36
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 2048, 1, 1]          --
# |    └─Conv2d: 2-1                       [-1, 64, 112, 112]        (9,408)
# |    └─BatchNorm2d: 2-2                  [-1, 64, 112, 112]        (128)
# |    └─ReLU: 2-3                         [-1, 64, 112, 112]        --
# |    └─MaxPool2d: 2-4                    [-1, 64, 56, 56]          --
# |    └─Sequential: 2-5                   [-1, 256, 56, 56]         --
# |    |    └─Bottleneck: 3-1              [-1, 256, 56, 56]         (75,008)
# |    |    └─Bottleneck: 3-2              [-1, 256, 56, 56]         (70,400)
# |    |    └─Bottleneck: 3-3              [-1, 256, 56, 56]         (70,400)
# |    └─Sequential: 2-6                   [-1, 512, 28, 28]         --
# |    |    └─Bottleneck: 3-4              [-1, 512, 28, 28]         (379,392)
# |    |    └─Bottleneck: 3-5              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-6              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-7              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-8              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-9              [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-10             [-1, 512, 28, 28]         (280,064)
# |    |    └─Bottleneck: 3-11             [-1, 512, 28, 28]         (280,064)
# |    └─Sequential: 2-7                   [-1, 1024, 14, 14]        --
# |    |    └─Bottleneck: 3-12             [-1, 1024, 14, 14]        (1,512,448)
# |    |    └─Bottleneck: 3-13             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-14             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-15             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-16             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-17             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-18             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-19             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-20             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-21             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-22             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-23             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-24             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-25             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-26             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-27             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-28             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-29             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-30             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-31             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-32             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-33             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-34             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-35             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-36             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-37             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-38             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-39             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-40             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-41             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-42             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-43             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-44             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-45             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-46             [-1, 1024, 14, 14]        (1,117,184)
# |    |    └─Bottleneck: 3-47             [-1, 1024, 14, 14]        (1,117,184)
# |    └─Sequential: 2-8                   [-1, 2048, 7, 7]          --
# |    |    └─Bottleneck: 3-48             [-1, 2048, 7, 7]          (6,039,552)
# |    |    └─Bottleneck: 3-49             [-1, 2048, 7, 7]          (4,462,592)
# |    |    └─Bottleneck: 3-50             [-1, 2048, 7, 7]          (4,462,592)
# |    └─AdaptiveAvgPool2d: 2-9            [-1, 2048, 1, 1]          --
# ├─Linear: 1-2                            [-1, 256]                 524,544
# ├─BatchNorm1d: 1-3                       [-1, 256]                 512
# ==========================================================================================
# Total params: 58,668,864
# Trainable params: 525,056
# Non-trainable params: 58,143,808
# Total mult-adds (G): 11.33
# ==========================================================================================
# Input size (MB): 18.38
# Forward/backward pass size (MB): 321.18
# Params size (MB): 223.80
# Estimated Total Size (MB): 563.36
# ==========================================================================================
# EPOCH: 1.000  trn_loss: 3.318  val_loss: 2.611  (346.04s - 1384.15s remaining)
# EPOCH: 2.000  trn_loss: 2.487  val_loss: 2.385  (691.98s - 1037.96s remaining)
# EPOCH: 3.000  trn_loss: 2.251  val_loss: 2.264  (1024.46s - 682.97s remaining)
# EPOCH: 4.000  trn_loss: 2.091  val_loss: 2.227  (1349.31s - 337.33s remaining)
# EPOCH: 5.000  trn_loss: 2.057  val_loss: 2.211  (1667.32s - 0.00s remaining)
# 100%|██████████| 106/106 [00:00<00:00, 3190.61it/s]
# tensor[1, 3, 224, 224] n=150528 x∈[-2.118, 2.640] μ=-0.925 σ=0.975 cuda:0
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.9/bdb.py", line 334, in set_trace
#     sys.settrace(self.trace_dispatch)
# > <ipython-input-9-37a4ce46c249>(69)predict()
# -> for i in range(self.max_seq_length):
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.9/bdb.py", line 345, in set_continue
#     sys.settrace(None)
# > <ipython-input-9-37a4ce46c249>(100)predict()
# -> sentences.append(sentence)
# --KeyboardInterrupt--
# > <ipython-input-9-37a4ce46c249>(204)load_image_and_predict()
# -> show(org_image, title=sentence)
# (Pdb) c
